# %% [markdown]
# <a href="https://colab.research.google.com/github/khanhdang/Colab-ImageProcessing/blob/master/5_2__haris_corner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf *.jpg
# !rm -rf *.png

# %%
import cv2
import numpy as np
from google.colab import files
#file=files.upload()
# !wget https://i.imgur.com/QQPQ0GD.png -O input.jpg
#!wget https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Coat_of_arms_of_Croatia.svg/200px-Coat_of_arms_of_Croatia.svg.png -O input.jpg
# Out:
# --2019-03-14 00:55:14--  https://i.imgur.com/QQPQ0GD.png
# Resolving i.imgur.com (i.imgur.com)... 151.101.248.193
# Connecting to i.imgur.com (i.imgur.com)|151.101.248.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72680 (71K) [image/png]
# Saving to: ‘input.jpg’
#
# input.jpg           100%[===================>]  70.98K  --.-KB/s    in 0.02s
#
# 2019-03-14 00:55:14 (2.80 MB/s) - ‘input.jpg’ saved [72680/72680]

# %%
filename = 'input.jpg'

img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

#cv2.imshow('dst',img)


cv2.imwrite('output.jpg',img)
# Out:
# True

# %%
files.download('output.jpg')
import matplotlib.pyplot as plt
imgplot = plt.imshow(img)
