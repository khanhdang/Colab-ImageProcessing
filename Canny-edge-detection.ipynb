# %% [markdown]
# <a href="https://colab.research.google.com/github/khanhdang/Colab-ImageProcessing/blob/master/Canny-edge-detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm *.jpg*
# !ls
# Out:
# rm: cannot remove '*.jpg*': No such file or directory
# sample_data

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/Wikipedia-logo-v2.svg/360px-Wikipedia-logo-v2.svg.png -O input.jpg
# !ls
# Out:
# --2020-04-10 07:10:44--  https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/Wikipedia-logo-v2.svg/360px-Wikipedia-logo-v2.svg.png
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.154.240, 2620:0:861:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.154.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98167 (96K) [image/png]
# Saving to: ‘input.jpg’
#
# input.jpg           100%[===================>]  95.87K  --.-KB/s    in 0.03s
#
# 2020-04-10 07:10:44 (2.99 MB/s) - ‘input.jpg’ saved [98167/98167]
#
# input.jpg  sample_data

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('input.jpg',0)
edges = cv2.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()
